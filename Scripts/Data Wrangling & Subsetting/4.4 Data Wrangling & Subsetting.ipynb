# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Data files

# %%
#path to data folder
working_directory = os.getcwd()
print(working_directory)
# Out:
# /Users/schitchards/Documents/Data Analytics/Programming/Instacart Basket Analysis/03 Scripts

# %%
path=r'/Users/schitchards/Documents/Data Analytics/Programming/Instacart Basket Analysis'

# %%
#importing orders/products/departments datafiles
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %% [markdown]
# ## Excercise wrangling procedures

# %%
# Dropping column
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
#Renaming order_dow column
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)
df_ords.head(100)
# Out:
#    order_id user_id  transaction_count  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1                  1                   2                  8
# 1   2398795       1                  2                   3                  7
# 2    473747       1                  3                   3                 12
# 3   2254736       1                  4                   4                  7
# 4    431534       1                  5                   4                 15
# ..      ...     ...                ...                 ...                ...
# 95  1468214      11                  7                   5                  9
# 96  1376945      11                  8                   6                 11
# 97  1483446      12                  1                   1                 12
# 98  1247527      12                  2                   5                  9
# 99  1916106      12                  3                   5                  8
#
#     days_since_prior_order
# ...

# %%
#Changing a variable's Data Type
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep_t = df_dep.T
df_dep_t.head()
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the first row of df_dep_t for the header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#Creating data dictionary for df_prods
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#Using data dictionary in practice
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
#Subsetting/creating a smaller data set using a filter
df_snacks = df_prods[df_prods['department_id']==19]

# %% [markdown]
# ## Task wrangling procedures

# %%
#2. Changing a variable's Data Type
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
df_ords['user_id'].value_counts(dropna=False)
# Out:
# 152340    100
# 185641    100
# 185524    100
# 81678     100
# 70922     100
#          ...
# 13046       4
# 70208       4
# 111440      4
# 31762       4
# 47980       4
# Name: user_id, Length: 206209, dtype: int64

# %%
#4. Frequency of order_hour_of_day
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# The busiest hour for placing orders is at 10am

# %%
#5 Determine the meaning of 4 in the department id column for df_prods
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# department_id of 4 = produce

# %%
#6 Subset for only breakfast item sales
df_breakfast = df_prods[df_prods ['department_id']==4]

# %%
#7 All observations from the following departments: alcohol, deli, beverages, meat/seafood
df_dinner_parties = df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]
df_dinner_parties.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 6            7                     Pure Coconut Water With Orange        98
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 16          17                                  Rendered Duck Fat        35
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38          39           Daily Tangerine Citrus Flavored Beverage        64
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43          44                        Sparkling Raspberry Seltzer       115
# ...

# %%
#8 Rows in df_dinner_parties
df_dinner_parties.shape
# Out:
# (7650, 5)

# %% [markdown]
# 7650 rows in the df_dinner_parties dataframe

# %%
#9. Extract info about 'user_id' 1
df_ords[df_ords['user_id']==1]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, transaction_count, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
df_user_id.head()
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, transaction_count, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
#10 Desciptive stats on user_id = 1
df_user_id.describe()
# Out:
#        transaction_count  orders_day_of_week  order_hour_of_day  \
# count                0.0                 0.0                0.0
# mean                 NaN                 NaN                NaN
# std                  NaN                 NaN                NaN
# min                  NaN                 NaN                NaN
# 25%                  NaN                 NaN                NaN
# 50%                  NaN                 NaN                NaN
# 75%                  NaN                 NaN                NaN
# max                  NaN                 NaN                NaN
#
#        days_since_prior_order
# count                     0.0
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
df_ords.to_csv(os.path.join(path,'02 Data','Prepared Data','orders_wrangled.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path,'02 Data','Prepared Data','departments_wrangled.csv'))
